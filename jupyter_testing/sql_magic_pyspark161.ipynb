# %% [markdown]
# # To use sql_magic:
# * Must use spark version > 2.0.0

# %%
import sys, os
print sc

# %%
# Print path to make sure we are in right place
print sys.executable
# Out:
# /home/tnystrand/anaconda2/envs/py27/bin/python

# %%
df_burst = sqlCtx.sql("select count(*) as counts, partition_date from burst_time_series_patchjoin where partition_date>'2017-09-01' group by partition_date").collect()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-3-e52f1e344790> in <module>()
# ----> 1 df_burst = sqlCtx.sql("select count(*) as counts, partition_date from burst_time_series_patchjoin where partition_date>'2017-09-01' group by partition_date").collect()
#
# /opt/alti-spark-1.6.1/python/pyspark/sql/context.py in sql(self, sqlQuery)
#     578         [Row(f1=1, f2=u'row1'), Row(f1=2, f2=u'row2'), Row(f1=3, f2=u'row3')]
#     579         """
# --> 580         return DataFrame(self._ssql_ctx.sql(sqlQuery), self)
#     581
#     582     @since(1.0)
#
# /opt/alti-spark-1.6.1/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
# --> 813             answer, self.gateway_client, self.target_id, self.name)
#     814
# ...

# %%
sqlCtx
